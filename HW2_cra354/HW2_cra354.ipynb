# %%
import pandas as pd
import os
import pylab as pl

# %%
''' Check that environmental variable DFDATA exists
 and points to /gws/open/NYCOpenData/nycopendata/data/
'''
print(os.environ['DFDATA'])
# Out:
# /gws/open/NYCOpenData/nycopendata/data

# %%
# Go to $DFDATA
os.chdir(os.environ['DFDATA'])
# Find which dir has usable data 
os.listdir()
# Out:
# ['3vw7-n665',
#  'pg99-2ihy',
#  'n7a9-2re6',
#  'n25p-mqr7',
#  '724b-yxwa',
#  'rb57-v5kw',
#  'isne-8yvc',
#  'ba83-5a9z',
#  '9ajw-ec2m',
#  '4k83-5vax',
#  'k7pu-jdzv',
#  'tn5i-59fq',
#  '7zcz-5cj4',
#  'biuh-wvui',
#  'a6d4-r7hy',
#  '6632-q9k6',
#  '5p78-k3zm',
#  '489r-gebn',
#  'wife-azmd',
#  'msz8-hedd',
#  'qnrn-btkx',
#  'hyim-vn3z',
#  's55k-dz26',
#  'rjk8-wvxn',
#  'hdyh-hbhz',
#  '5k8n-8zmj',
#  '6eig-hpna',
#  'r3f3-nuxb',
#  'wjn4-mu56',
#  'tyjc-9rwy',
#  't9jy-gfev',
#  'bkyy-g74a',
#  '4838-wvrc',
#  'jkiz-wt49',
#  'gjvh-6q28',
#  'qk7k-5gsp',
#  '59gn-q4ai',
#  'b9hh-z47x',
#  'suzb-56dw',
#  't25w-5t5u',
#  '99i6-msyy',
#  'd84z-5kap',
#  'fvrb-kbbt',
#  'xtyk-k9qh',
#  '7izi-r365',
#  'mqpq-em9h',
#  '52u9-r7dj',
#  'i6c2-fwnr',
#  '2xe8-hy6s',
#  'h3zm-ta5h',
#  'dgi5-y287',
#  'dzgh-ja44',
#  'n3ye-6ajc',
#  'n8ep-94r7',
#  'a7hj-s5px',
#  'wbrk-qbz8',
#  'e92m-49rb',
#  '4y5p-g6ae',
#  '8rmt-vnew',
#  'ktas-47y7',
#  '8qgy-ka3v',
#  'ug5r-ddzb',
# ...

# %%
os.chdir(os.environ['DFDATA'] + '/z57s-qzmg' + '/1409922747')

# %%
# Read in file
df = pd.read_csv('z57s-qzmg')

# %%
# Display head of df
df.head()
# Out:
#    Unique Key            Created Date             Closed Date Complaint Type  \
# 0     2733064  01/28/2005 12:00:00 AM  03/09/2005 12:00:00 AM          Noise
# 1     2733068  01/28/2005 12:00:00 AM  03/01/2005 12:00:00 AM          Noise
# 2     2734810  02/02/2005 12:00:00 AM  02/18/2005 12:00:00 AM          Noise
# 3     2734848  02/04/2005 12:00:00 AM  02/07/2005 12:00:00 AM          Noise
# 4     2738249  02/17/2005 12:00:00 AM  03/11/2005 12:00:00 AM          Noise
#
#                                           Descriptor  Location Type  \
# 0  Noise: Air Condition/Ventilation Equip, Reside...            NaN
# 1  Noise: Air Condition/Ventilation Equip, Commer...            NaN
# 2                               Noise: Vehicle (NR2)            NaN
# 3                           Noise, Barking Dog (NR5)            NaN
# 4                Noise: Construction Equipment (NJ4)            NaN
#
#    Incident Zip      Incident Address       Street Name    Cross Street 1  \
# ...

# %%
# Drop all but the latitude and longitude columns
df.drop(list(df)[:-2], inplace=True, axis=1)

# %%
# Display the reduced dataframe
df
# Out:
#         Latitude  Longitude
# 0      40.736759 -74.006557
# 1      40.769579 -73.966237
# 2      40.804168 -73.966700
# 3      40.798244 -73.962571
# 4      40.779362 -73.953151
# 5      40.769059 -73.961100
# 6      40.766957 -73.961906
# 7      40.705148 -74.009983
# 8      40.707294 -74.012090
# 9      40.721576 -73.997760
# 10     40.756603 -73.968731
# 11     40.715433 -74.007543
# 12     40.791307 -73.969848
# 13     40.769059 -73.961100
# 14     40.740443 -74.002021
# 15     40.792412 -73.973427
# 16     40.786909 -73.956478
# 17     40.784949 -73.948734
# 18     40.732008 -73.993949
# 19     40.707294 -74.012090
# 20     40.764138 -73.986614
# 21     40.768710 -73.960288
# 22     40.745814 -74.005532
# 23     40.732472 -73.989374
# 24     40.710207 -74.004188
# 25     40.749357 -73.981799
# 26     40.735433 -73.982694
# 27     40.736005 -73.993617
# 28     40.801942 -73.957462
# 29     40.773249 -73.956982
# ...          ...        ...
# 18096  40.783776 -73.981956
# ...

# %%
# Plot the two numeric columns
# %pylab inline
pl.scatter(df['Longitude'], df['Latitude'])
pl.title('Coordinates of Something in Manhattan', fontsize=15)
pl.xlabel('Longitide', fontsize=12)
pl.ylabel('Latitude', fontsize=12)
# Out:
# Populating the interactive namespace from numpy and matplotlib
